# %% [markdown]
# # Python Training for Pandas (Matt Harison Oreilly)

# %% [markdown]
# The below first line is there to display graphs inline in the notebook.

# %%
# to display graphs in the notepad.
# %matplotlib inline 
import pandas as pd 
import matplotlib 
import numpy as np

# %% [markdown]
# To Get the current directory and change it accordingly.

# %%
import os 

os.getcwd() # get present dir
os.chdir('C:\Python\Python_programs')
os.getcwd()
# Out:
# 'C:\\Python\\Python_programs'

# %%
pd.read_csv?

# %%
nyc = pd.read_csv('central_park.csv', parse_dates=[0])
nyc.head()
# Out:
#          EST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2006-01-01              42.0               37.0              32.0
# 1 2006-01-02              48.0               44.0              39.0
# 2 2006-01-03              40.0               37.0              33.0
# 3 2006-01-04              38.0               34.0              29.0
# 4 2006-01-05              50.0               44.0              37.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            32.0            30.0           28.0          85.0
# 1            38.0            34.0           29.0          92.0
# 2            38.0            33.0           26.0          92.0
# 3            36.0            26.0           19.0          85.0
# 4            38.0            35.0           32.0          92.0
#
#     Mean Humidity   Min Humidity  ...   Max VisibilityMiles  \
# 0            74.0           62.0  ...                  10.0
# ...

# %% [markdown]
# # Assignment on El Nino data set

# %%
names=names = '''obs
year
month
day
date
latitude
longitude
zon.winds
mer.winds
humidity
air temp.
s.s.temp.'''.split('\n')

nino= pd.read_csv('tao-all2.dat',sep=' ', names=names, na_values='.', parse_dates=[[1,2,3]])
nino.head()
