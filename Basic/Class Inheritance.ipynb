# %%
# Using Python Class Variables. 
class employee:
    
    raise_amt = 1.04
    
    instance_count = 0
    
    def __init__(self,fname,lname,pay):
        self.fname = fname
        self.lname = lname
        self.pay = pay
        self.email = fname+'.'+lname+'@comp.com'
        employee.instance_count +=1 
        
    def fullName(self):
        return ' {0} , {1}'.format(self.fname,self.lname)
    
    def raisePay(self):
        self.pay = int(self.raise_amt * self.pay)
    
class developer(employee):
    raise_amt = 1.1
    
    
ob1 = developer('N','C',14000)
ob2 = employee('Test','User',16000)

print("Pay",ob1.pay)
ob1.raisePay()

#print("Mail",ob1.email)
print("Pay",ob1.pay)
# Out:
# Pay 14000
# Pay 15400

# %%
class employee:
    
    raise_amt = 1.04
    
    instance_count = 0
    
    def __init__(self,fname,lname,pay):
        self.fname = fname
        self.lname = lname
        self.pay = pay
        self.email = fname+'.'+lname+'@comp.com'
        employee.instance_count +=1 
        
    def fullName(self):
        return ' {0} , {1}'.format(self.fname,self.lname)
    
    def raisePay(self):
        self.pay = int(self.raise_amt * self.pay)
    
class developer(employee):
    raise_amt = 1.1
    
    def __init__(self,fname,lname,pay,prog_lang):
        super().__init__(fname,lname,pay)
        self.prog_lang=prog_lang
    
    
    
ob1 = developer('N','C',14000,'Python')
ob2 = developer('Test','User',16000,'Java')

print(ob1.email)
print(ob1.prog_lang)
# Out:
# N.C@comp.com
# Python

# %%
class employee:
    
    raise_amt = 1.04
    
    instance_count = 0
    
    def __init__(self,fname,lname,pay):
        self.fname = fname
        self.lname = lname
        self.pay = pay
        self.email = fname+'.'+lname+'@comp.com'
        employee.instance_count +=1 
        
    def fullName(self):
        return ' {0} , {1}'.format(self.fname,self.lname)
    
    def raisePay(self):
        self.pay = int(self.raise_amt * self.pay)
    
class developer(employee):
    raise_amt = 1.1
    
    def __init__(self,fname,lname,pay,prog_lang):
        super().__init__(fname,lname,pay)
        self.prog_lang=prog_lang

class manager(employee):
    
    def __init__(self,fname,lname,pay,employee=None):
        super().__init__(fname,lname,pay)
        if employee is None:
            self.employee = []
        else:
            self.employee = employee
    
    def add_emp(self,emp):
        if emp not in self.employee:
            self.employee.append(emp)
        
    def rem_emp(self,emp):
        if emp in self.employee:
            self.employee.remove(emp)
            
            
    def all_emp(self):
        for emp in self.employee:
            print("-->",emp.fullName())
            
    
    
ob1 = developer('N','C',14000,'Python')
ob2 = developer('Test','User',16000,'Java')

mg1 = manager('Ankit','Chandra',90000,[ob1])

print(mg1.email)

mg1.add_emp(ob2)
mg1.rem_emp(ob1)
mg1.all_emp()

#print(ob1.email)
#print(ob1.prog_lang)
# Out:
# Ankit.Chandra@comp.com
# -->  Test , User

# %%
class employee:
    
    raise_amt = 1.04
    
    instance_count = 0
    
    def __init__(self,fname,lname,pay):
        self.fname = fname
        self.lname = lname
        self.pay = pay
        self.email = fname+'.'+lname+'@comp.com'
        employee.instance_count +=1 
        
    def fullName(self):
        return ' {0} , {1}'.format(self.fname,self.lname)
    
    def raisePay(self):
        self.pay = int(self.raise_amt * self.pay)
    
class developer(employee):
    raise_amt = 1.1
    
    def __init__(self,fname,lname,pay,prog_lang):
        super().__init__(fname,lname,pay)
        self.prog_lang=prog_lang

class manager(employee):
    
    def __init__(self,fname,lname,pay,employee=None):
        super().__init__(fname,lname,pay)
        if employee is None:
            self.employee = []
        else:
            self.employee = employee
    
    def add_emp(self,emp):
        if emp not in self.employee:
            self.employee.append(emp)
        
    def rem_emp(self,emp):
        if emp in self.employee:
            self.employee.remove(emp)
            
            
    def all_emp(self):
        for emp in self.employee:
            print("-->",emp.fullName())
            
    
    
ob1 = developer('N','C',14000,'Python')
ob2 = developer('Test','User',16000,'Java')

mg1 = manager('Ankit','Chandra',90000,[ob1])

print(isinstance(mg1,employee))
print(isinstance(ob2,employee))
print(isinstance(ob2,developer))
print(isinstance(ob2,manager))

print(issubclass(manager,employee))
print(issubclass(developer,employee))
print(issubclass(developer,manager))
# Out:
# True
# True
# True
# False
# True
# True
# False
